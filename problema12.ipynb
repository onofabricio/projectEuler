# %% [markdown]
# ## Highly divisible triangular number
# Problem 12
#
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#  1: 1 \
#  3: 1,3 \
#  6: 1,2,3,6 \
# 10: 1,2,5,10 \
# 15: 1,3,5,15 \
# 21: 1,3,7,21 \
# 28: 1,2,4,7,14,28 \
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
n=0
divisores = []
maior_nr_divisores = 0
while len(divisores)<500:
    n=n+1
    numero_triangular = sum([i for i in range(1, n)])
    divisores = [i for i in range(1, numero_triangular+1) if numero_triangular%i == 0]
    if len(divisores)>maior_nr_divisores:
        maior_nr_divisores = len(divisores)
    print(maior_nr_divisores)
    
print(numero_triangular)
print(divisores)
print(len(divisores))
# Out:
# 0
# 1
# 2
# 4
# 4
# 4
# 4
# 6
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 18
# 18
# 18
# 18
# 18
# 18
# 18
# 18
# 20
# 20
# 20
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# ...

# %%
#User: ewilli14

import math
from datetime import time

def triangle_numbers(counter):
    c = 0
    for n in range(1,counter+1):
        c += n
    return c

def num_divisors(number):
    divisors = []
    for n in range(1,int(math.sqrt(number))+1):
        if number % n == 0:
            divisors.append(n)
            divisors.append(number / n)
    return divisors

i = 1
num = int(input('Enter # of divisors: '))

while True:
    divisors = []
    tri_num = triangle_numbers(i)
    divisors = num_divisors(tri_num)
    if len(divisors) >= num:
        break
    i += 1

print(tri_num)
# Out:
# 76576500

# %%
#User : pineconepinecone

import math
def divsors(n):
    return len([i for i in range(1,round(math.sqrt(n))) if n%i == 0])
n = 1
while(divsors(round((n+1)*n/2)) <= 250):
    n+=1
print(n*(n+1)/2)
# Out:
# 76576500.0
